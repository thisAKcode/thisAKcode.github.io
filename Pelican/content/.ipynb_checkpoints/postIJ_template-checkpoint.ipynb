# %% [markdown]
# - title: Test.
# - author: Alex
# - date: 1988-02-02
# - category: life

# %% [markdown]
# ### Topic
# Here is an example of how you can write Pelican blog using Jupyter Notebooks.
#
# Well you use markdown (.md), everything you need for writing in md is documented here [github](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax).
#
# ##### maths
# In a Jupyter notebook, you can directly use LaTeX within Markdown cells. Here's version for Jupyter (psst no need for backslashes):
# $$
#  P(A|B) = \frac{P(B|A) \, P(A)}{P(B)}
# $$
#
# ##### links
# This blog is hosted using [PrettyLagom GitHub Pages](https://www.prettylagom.me/)
# ##### tables
#
#
# | Column 1 | Column 2 | Column 3 |
# |-----------|-----------|-----------|
# | Lorem ipsum | Dolor sit amet | Consectetur adipiscing elit |
# | Sed do | Eiusmod tempor | Incididunt ut labore |
# | Et dolore | Magna aliqua | Ut enim ad minim veniam |
# | Quis nostrud | Exercitation ullamco | Laboris nisi ut aliquip |
# | Ex ea | Commodo consequat | Duis aute irure dolor |
#
#
# ##### etc
# ##### etc
