# %% [markdown]
# - title: python library Whitebox
# - author: Alex
# - date: 2025-11-04
# - category: python

# %% [markdown]
# ### Python Library Whitebox
# Here is an example of n methods that I discovered recently in Python library Whitebox.
#
# Well I am interested in processing geotiff and want to use [whitebox](https://www.whiteboxgeo.com/wbw-installation/) for that. Get the library [here](https://pypi.org/project/whitebox/). Here is a good place to start: [WhiteboxTools Python API Documentation](https://www.whiteboxgeo.com/manual/wbt_book/intro.html) or [jupyter notebook examples](https://colab.research.google.com/github/giswqs/whitebox-python/blob/master/examples/whitebox.ipynb
# ##### My First Case
# Read a geotiff file and get its basic info:
# ```python
# from whitebox.whitebox_tools import WhiteboxTools
#
# wbt = WhiteboxTools()
# wbt.set_working_dir("C:\\thisAKcode.github.io\\Pelican\\content\\other")
# wbt.read_geotiff("Terrain_S_878.tif")
# ```
#
# | Et dolore | Magna aliqua | Ut enim ad minim veniam |
# | Quis nostrud | Exercitation ullamco | Laboris nisi ut aliquip |
# | Ex ea | Commodo consequat | Duis aute irure dolor |
#
#
#
# ##### etc
# ##### etc

# %%
from importlib_resources import files

from whitebox.whitebox_tools import WhiteboxTools
import os
from importlib_resources import files
data_dir = r"C:\\thisAKcode.github.io\\Pelican\\content\\other"
print(os.listdir(data_dir))
wbt = WhiteboxTools()
# set whitebox working directory
#wbt.set_working_dir(data_dir)
#wbt.verbose = False
'''
# identify the sample data directory of the package
data_dir = str(files("whitebox").joinpath("testdata"))
wbt = WhiteboxTools()
# set whitebox working directory
wbt.set_working_dir(data_dir)
wbt.verbose = False


# wbt = whitebox.WhiteboxTools()
testdata_path = files("whitebox").joinpath("data")

#wbt.set_working_dir("C:\\thisAKcode.github.io\\Pelican\\content\\other")
# wbt.read_geotiff("Terrain_S_878.tif")
'''
# Out:
# ['beatles_auth.csv', 'CSV.csv', 'herbs.csv', 'Terrain_S_878.tif']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-f20ad6f993c1> in <module>
#       6 data_dir = r"C:\\thisAKcode.github.io\\Pelican\\content\\other"
#       7 print(os.listdir(data_dir))
# ----> 8 wbt = WhiteboxTools()
#       9 # set whitebox working directory
#      10 #wbt.set_working_dir(data_dir)
#
# ~\AppData\Roaming\Python\Python37\site-packages\whitebox\whitebox_tools.py in __init__(self)
#     312         self.__compress_rasters = False
#     313         self.__max_procs = -1
# --> 314         download_wbt()
#     315
#     316         if os.path.isfile("settings.json"):
#
# ~\AppData\Roaming\Python\Python37\site-packages\whitebox\whitebox_tools.py in download_wbt(linux_musl, reset, verbose)
#      57     # Get package directory
#      58     pkg_dir = os.path.dirname(
# ...

# %%
import whitebox
